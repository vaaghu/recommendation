# %%
# !apt-get -qq update
# !apt-get -qq install git
# !pip install kaggle

# %%
HOME = "/content/drive/MyDrive/Colab_Notebooks/recommendation"

# %%
# !mkdir -p ~/.kaggle
# !cp $HOME/datasets/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# !git clone https://github.com/vaaghu/recommendation.git $HOME
# Out:
# Cloning into '/content/drive/MyDrive/Colab_Notebooks/recommendation'...
# remote: Enumerating objects: 18, done.
# remote: Counting objects: 100% (18/18), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 18 (delta 5), reused 7 (delta 2), pack-reused 0
# Receiving objects: 100% (18/18), 27.40 KiB | 1.19 MiB/s, done.
# Resolving deltas: 100% (5/5), done.

# %%
# !mkdir $HOME/datasets
# Out:
# mkdir: cannot create directory ‘/content/drive/MyDrive/Colab_Notebooks/recommendation/datasets’: File exists

# %%
# !kaggle datasets download -d hernan4444/anime-recommendation-database-2020 -p $HOME/datasets/
# Out:
# ...
#  99% 656M/661M [00:09<00:00, 49.6MB/s]
# 100% 661M/661M [00:09<00:00, 69.5MB/s]

# %%
# !unzip $HOME/datasets/anime-recommendation-database-2020.zip -d $HOME/datasets/
# Out:
# Archive:  /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/anime-recommendation-database-2020.zip
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/anime.csv
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/anime_with_synopsis.csv
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/animelist.csv
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/html folder/html/1/details.html
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/html folder/html/1/pictures.html
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/html folder/html/1/recomendations.html
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/html folder/html/1/reviews_1.html
#   inflating: /content/drive/MyDrive/Colab_Notebooks/recommendation/datasets/html folder/html/1/reviews_10.html
# ...

# %%
# %cd $HOME
# Out:
# /content/drive/MyDrive/Colab_Notebooks/recommendation
# # github.com:22 SSH-2.0-babeld-d815c248
# # github.com:22 SSH-2.0-babeld-d815c248
# # github.com:22 SSH-2.0-babeld-d815c248
# # github.com:22 SSH-2.0-babeld-d815c248
# # github.com:22 SSH-2.0-babeld-d815c248

# %%
# !git
# Out:
# Updating ced40ac..8a09895
# Fast-forward
#  main.ipynb | 133 ++++++++++++++++++++++---------------------------------------
#  1 file changed, 47 insertions(+), 86 deletions(-)

# %%
# !mkdir -p ~/.ssh && touch ~/.ssh/known_hosts && ssh-keyscan github.com >> ~/.ssh/known_hosts
# Out:
# # github.com:22 SSH-2.0-babeld-c89ab1f3
# # github.com:22 SSH-2.0-babeld-d815c248
# # github.com:22 SSH-2.0-babeld-d815c248
# # github.com:22 SSH-2.0-babeld-d815c248
# # github.com:22 SSH-2.0-babeld-d815c248

# %%
# !ssh -T git@github.com
# Out:
# Hi vaaghu! You've successfully authenticated, but GitHub does not provide shell access.
